# %%
import networkx as nx
G=nx.karate_club_graph()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pos=nx.spring_layout(G)
nx.draw(G,pos,node_color='#A0CBE2',edge_color='k',width=2,with_labels=True)

# %%
G.number_of_nodes()
# Out:
# 34

# %%
G.number_of_edges()
# Out:
# 78

# %%
G.degree()
# Out:
# {0: 16,
#  1: 9,
#  2: 10,
#  3: 6,
#  4: 3,
#  5: 4,
#  6: 4,
#  7: 4,
#  8: 5,
#  9: 2,
#  10: 3,
#  11: 1,
#  12: 2,
#  13: 5,
#  14: 2,
#  15: 2,
#  16: 2,
#  17: 2,
#  18: 2,
#  19: 3,
#  20: 2,
#  21: 2,
#  22: 2,
#  23: 5,
#  24: 3,
#  25: 3,
#  26: 2,
#  27: 4,
#  28: 3,
#  29: 4,
#  30: 4,
#  31: 6,
#  32: 12,
#  33: 17}

# %%
nx.diameter(G)
# Out:
# 5

# %%
nx.transitivity(G)
# Out:
# 0.2556818181818182

# %%
nx.average_clustering(G)
# Out:
# 0.5706384782076823

# %%
nx.clustering(G)
# Out:
# {0: 0.15,
#  1: 0.3333333333333333,
#  2: 0.24444444444444444,
#  3: 0.6666666666666666,
#  4: 0.6666666666666666,
#  5: 0.5,
#  6: 0.5,
#  7: 1.0,
#  8: 0.5,
#  9: 0.0,
#  10: 0.6666666666666666,
#  11: 0.0,
#  12: 1.0,
#  13: 0.6,
#  14: 1.0,
#  15: 1.0,
#  16: 1.0,
#  17: 1.0,
#  18: 1.0,
#  19: 0.3333333333333333,
#  20: 1.0,
#  21: 1.0,
#  22: 1.0,
#  23: 0.4,
#  24: 0.3333333333333333,
#  25: 0.3333333333333333,
#  26: 1.0,
#  27: 0.16666666666666666,
#  28: 0.3333333333333333,
#  29: 0.6666666666666666,
#  30: 0.5,
#  31: 0.2,
#  32: 0.19696969696969696,
#  33: 0.11029411764705882}

# %%
nx.triangles(G)
# Out:
# {0: 18,
#  1: 12,
#  2: 11,
#  3: 10,
#  4: 2,
#  5: 3,
#  6: 3,
#  7: 6,
#  8: 5,
#  9: 0,
#  10: 2,
#  11: 0,
#  12: 1,
#  13: 6,
#  14: 1,
#  15: 1,
#  16: 1,
#  17: 1,
#  18: 1,
#  19: 1,
#  20: 1,
#  21: 1,
#  22: 1,
#  23: 4,
#  24: 1,
#  25: 1,
#  26: 1,
#  27: 1,
#  28: 1,
#  29: 4,
#  30: 3,
#  31: 3,
#  32: 13,
#  33: 15}

# %%
degree_sequence=sorted(nx.degree(G).values(),reverse=True)
plt.hist(degree_sequence,color='b')
# Out:
# (array([ 12.,  12.,   3.,   2.,   0.,   2.,   1.,   0.,   0.,   2.]),
#  array([  1. ,   2.6,   4.2,   5.8,   7.4,   9. ,  10.6,  12.2,  13.8,
#          15.4,  17. ]),
#  <a list of 10 Patch objects>)

# %%
A=nx.to_numpy_matrix(G)

import numpy as np
N=nx.number_of_nodes(G); Ap = np.zeros((N,N,3)); Ap[A==1]=[1,1,1]; Ap[A==0]=[0,0,0]

plt.imshow(A,cmap='gray',origin='lower')
